# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
oou = np.load('../tools/total_testset_window_errors.npy')

# %%
means = np.load('../tools/total_testset_mean_errors.npy')

# %%
means.shape
# Out:
# (741, 327)

# %%
oou.shape
# Out:
# (741, 327)

# %%
plt.hist(means[1,:], bins=65)
plt.show()

# %%
plt.hist(t[1,:], bins=65)
plt.show()

# %%
mean = np.mean(means, axis=1)

# %%
plt.plot(np.sort(mean))
